# %% [markdown]
# Soft Computing Exp-3

# %%
# Fuzzy sets
A = {"x1": 0.7, "x2": 0.4}
B = {"y1": 0.6, "y2": 0.8}
C = {"z1": 0.5, "z2": 0.9}

# -------------------------------
# 1. Cartesian Product (A x B)
# -------------------------------
R = {}  # Fuzzy relation R from A to B

for x in A:
    for y in B:
        R[(x, y)] = min(A[x], B[y])

print("Fuzzy Relation R (A x B):")
for key, value in R.items():
    print(key, ":", value)

# -------------------------------
# 2. Cartesian Product (B x C)
# -------------------------------
S = {}  # Fuzzy relation S from B to C

for y in B:
    for z in C:
        S[(y, z)] = min(B[y], C[z])

print("\nFuzzy Relation S (B x C):")
for key, value in S.items():
    print(key, ":", value)

# -------------------------------
# 3. Max-Min Composition (R o S)
# -------------------------------
composition = {}

for x in A:
    for z in C:
        min_values = []
        for y in B:
            min_values.append(min(R[(x, y)], S[(y, z)]))
        composition[(x, z)] = max(min_values)

print("\nMax-Min Composition (R o S):")
for key, value in composition.items():
    print(key, ":", value)
# Out:
# Fuzzy Relation R (A x B):
# ('x1', 'y1') : 0.6
# ('x1', 'y2') : 0.7
# ('x2', 'y1') : 0.4
# ('x2', 'y2') : 0.4
#
# Fuzzy Relation S (B x C):
# ('y1', 'z1') : 0.5
# ('y1', 'z2') : 0.6
# ('y2', 'z1') : 0.5
# ('y2', 'z2') : 0.8
#
# Max-Min Composition (R o S):
# ('x1', 'z1') : 0.5
# ('x1', 'z2') : 0.7
# ('x2', 'z1') : 0.4
# ('x2', 'z2') : 0.4
